# %%
from src.evaluation.df_utils import setup
from src.evaluation.experiment import run_experiment

# %%
d7p_path = 'outputs/clip_d7p.csv'
dmf_path = 'outputs/panderm_dmf.csv'
ham_path = 'outputs/clip_ham.csv'

# %%
X_train, y_train, X_test, y_test = setup(dmf_path, 'd7p')

# %%
import pandas as pd
df = pd.read_csv(dmf_path)
df.shape
# Out:
# (1211, 1028)

# %%
run_experiment(X_train, y_train, X_test, y_test, model_name = 'clip', data_name='dmf')
