# %%
from df_utils import setup
from experiment import run_experiment

# %%
d7p_path = '../../outputs/clip_d7p.csv'
dmf_path = '../../outputs/clip_dmf.csv'
ham_path = '../../outputs/clip_ham.csv'

# %%
X_train, y_train, X_test, y_test = setup(d7p_path, 'd7p')

# %%
run_experiment(X_train, y_train, X_test, y_test, model_name = 'clip', data_name='d7f')
# Out:
# Running experiment for CLIP  over D7F Dataset ....
#
#
# $$$$$$$$$$$$$$$ Results with: MLP $$$$$$$$$$$$$$$
#
# Training Task1...
# Current classes in MLP: [4 5]
# Task1 Accuracy: 86.67%
# Task1 Balanced Accuracy: 83.33%
#
# Training Task2...
# Current classes in MLP: [1 3]
# Task2 Accuracy: 98.32%
# Task2 Balanced Accuracy: 75.00%
#
# Training Task3...
# Current classes in MLP: [0 2]
# Task3 Accuracy: 91.53%
# Task3 Balanced Accuracy: 74.02%
#
# Total Average Accuracy: 92.17%
# Average Balanced Accuracy: 77.45%
#
#
# $$$$$$$$$$$$$$$ Results with: NMC Variations $$$$$$$$$$$$$$$
#
#
# ======= Results with: Base NMC ======
# Accuracy: 58.03%
# Balanced Accuracy: 46.01%
#
#
# ======= Results with: Base NMC & Normalization ======
# Accuracy: 58.55%
# Balanced Accuracy: 46.52%
#
#
# ======= Results with: Random Projection ======
# Accuracy: 53.37%
# Balanced Accuracy: 43.79%
#
#
# ======= Results with: Random Projection & Normalization ======
# Accuracy: 56.48%
# Balanced Accuracy: 43.63%
#
#
# ======= Results with: LDA ======
# Accuracy: 19.69%
# Balanced Accuracy: 28.57%
#
#
# ======= Results with: PCA ======
# Accuracy: 57.51%
# Balanced Accuracy: 45.86%
#
#
# ======= Results with: PCA & Normalization ======
# Accuracy: 58.03%
# Balanced Accuracy: 46.37%
